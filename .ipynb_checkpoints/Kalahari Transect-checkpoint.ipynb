# %%
import pandas as pd

# %%
dirname = 's2k_kt_stem_map_775/data/kt_stem_map_data_2000/'
filename = 'kt_stem_map_data_2000.csv'

df = pd.read_csv(dirname + filename)
print(df.columns)
# Out:
# Index(['SITE', 'SITE_NUM', 'NUMBER', 'X_METERS', 'Y_METERS', 'SPECIES_CODE',
#        'L1NUM', 'L1DBH', 'L2NUM', 'L2DBH', 'L3NUM', 'L3DBH', 'L4NUM', 'L4DBH',
#        'L5NUM', 'L5DBH', 'L6NUM', 'L6DBH', 'L7NUM', 'L7DBH', 'TOTLDBH',
#        'TOTLSTEM', 'TOTLBA', 'D1NUM', 'D1DBH', 'D2NUM', 'D2DBH', 'D3NUM',
#        'D3DBH', 'D4NUM', 'D4DBH', 'D5NUM', 'D5DBH', 'D6NUM', 'D6DBH', 'D7NUM',
#        'D7DBH', 'TOTDDBH', 'TOTDSTEM', 'TOTDBA', 'C1NUM', 'C1DBH', 'C2NUM',
#        'C2DBH', 'C3NUM', 'C3DBH', 'TOTCDBH', 'TOTCSTEM', 'TOTCBA', 'HEIGHT_1',
#        'HEIGHT_2', 'CANOPY_M', 'CANOPY2_M', 'AREAC', 'COPICE', 'DEAD',
#        'TOT_BIOM', 'LEAF_BIOM'],
#       dtype='object')

# %%
sites = df.groupby('SITE_NUM')
data = sites['HEIGHT_2'].mean()
data.plot()

# %%
biomass = sites['TOT_BIOM']
biomass.plot()
